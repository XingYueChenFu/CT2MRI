# %% [markdown]
# 下载`vgg19`

# %%
import torch

# 下载 VGG19 预训练模型
model = torch.hub.load('pytorch/vision', 'vgg19', pretrained=True)

# 保存到当前目录
torch.save(model.state_dict(), 'vgg19-dcbb9e9d.pth')
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/main" to /root/.cache/torch/hub/main.zip
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 4
#       1 import torch
#       3 # 下载 VGG19 预训练模型
# ----> 4 model = torch.hub.load('pytorch/vision', 'vgg19', pretrained=True)
#       6 # 保存到当前目录
#       7 torch.save(model.state_dict(), 'vgg19-dcbb9e9d.pth')
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/hub.py:647, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     637 if source == "github":
#     638     repo_or_dir = _get_cache_or_reload(
#     639         repo_or_dir,
#     640         force_reload,
#    (...)
#     644         skip_validation=skip_validation,
#     645     )
# --> 647 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     648 return model
#
# ...
